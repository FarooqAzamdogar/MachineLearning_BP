# %% [markdown]
# # Intermediate machine learnig with SKlearn

# %% [markdown]
# # 01. Simple Linear Regression

# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# simple linear regression
from sklearn.linear_model import LinearRegression
#load dataset from seaborn
df= sns.load_dataset('tips')
# selecting the features columns from df
X =  df[['total_bill']]
# selecting the label column from df
Y = df[['tip']]
# load the linear regression model
model= LinearRegression()
# fit the model
model.fit(X, Y)
# lets tip the  unknown and total_bill values
model.predict([[50]])
# Out:
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[6.17149548]])

# %%
# Reload the dataset to avoid overwriting the original df
df = sns.load_dataset('tips')
sns.lmplot(x='total_bill', y='tip', data=df)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Multiple linear Regression Or Multilinear Regression

# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
#load dataset from seaborn
df= sns.load_dataset('tips')
#encode smoker column with 0 and 1
df['smoker_num']= df['smoker'].map({'No':0, 'Yes':1})


# selecting the features columns from df
X =  df[['total_bill','size','smoker_num']]
# selecting the label column from df
Y = df[['tip']]
# load the linear regression model
model= LinearRegression()
# fit the model
model.fit(X, Y)
# lets tip the  unknown and total_bill values
print(model.predict([[40,2,0]]))
print(model.predict([[40,2,1]]))
# df.head()
# df.lmplot(x='total_bill', y='tip', data=df, hue='smoker')
# Out:
# [[4.82521423]]
# [[4.74178168]]
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Classicfication
# # Logistic Regression is Binary Clasification

# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import  LogisticRegression
#load dataset from seaborn
df= sns.load_dataset('tips')
# selecting the features columns from df
X =  df[['total_bill','size','tip']]
# selecting the label column from df
Y = df[['smoker']]
# load the linear regression model
model= LogisticRegression()
# fit the model
model.fit(X, Y)
# predict
print(model.predict([[10,2,3.5]]))
print(model.predict([[10,2,4.6]]))
# df.head()
# df.lmplot(x='total_bill', y='tip', data=df, hue='smoker')
# Out:
# ['No']
# ['No']
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # GaussianNB

# %%
#import libraries

import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
import seaborn as sns
#import naive bayes
from sklearn.naive_bayes import  GaussianNB
#load dataset from seaborn
df= sns.load_dataset('tips')
# selecting the features columns from df
X =  df[['total_bill','size','tip']]
# selecting the label column from df
Y = df[['smoker']]
# load the linear regression model
model= GaussianNB()
# fit the model
model.fit(X, Y)
# predict
print(model.predict([[10,2,3.5]]))
print(model.predict([[10,2,4.6]]))
# df.head()
# df.lmplot(x='total_bill', y='tip', data=df, hue='smoker')
# Out:
# ['No']
# ['No']
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Decision Tree Classifier

# %%
#import libraries

import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
import seaborn as sns
#import naive bayes
from sklearn.naive_bayes import  GaussianNB
# import decision tree
from sklearn.tree import DecisionTreeClassifier
#load dataset from seaborn
df= sns.load_dataset('tips')
# selecting the features columns from df
X =  df[['total_bill','size','tip']]
# selecting the label column from df
Y = df[['smoker']]
# load the linear regression model
model= DecisionTreeClassifier()
# fit the model
model.fit(X, Y)
# predict
print(model.predict([[10,2,3.5]]))
print(model.predict([[10,2,4.6]]))
# df.head()
# df.lmplot(x='total_bill', y='tip', data=df, hue='smoker')
# Out:
# ['Yes']
# ['Yes']
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Decision Tree Regressor

# %%
#import libraries

import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
import seaborn as sns
#import naive bayes
# from sklearn.naive_bayes import  GaussianNB
# import decision tree
from sklearn.tree import  DecisionTreeRegressor
#load dataset from seaborn
df= sns.load_dataset('tips')
# selecting the features columns from df
X =  df[['total_bill','size']]
# selecting the label column from df
Y = df[['tip']]
# load the linear regression model
model= DecisionTreeRegressor()
# fit the model
model.fit(X, Y)
# predict
print(model.predict([[10,2,]]))
print(model.predict([[10,2,]]))
# df.head()
# df.lmplot(x='total_bill', y='tip', data=df, hue='smoker')
# Out:
# [1.56]
# [1.56]
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# c:\Users\faroo\miniconda3\envs\python_ml\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Regression Metrics

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
import seaborn as sns
# import tensorflow as tf
from sklearn.linear_model import LinearRegression
#load dataset
df = sns.load_dataset('tips')
df.head()

X = df[['total_bill','size']]
Y = df[['tip']]

#train test split
from sklearn.model_selection import train_test_split
(X_train, X_test, Y_train, Y_test) = train_test_split(X,Y,test_size=0.2)
#call the model
model = LinearRegression()
#fit the model
model.fit(X_train,Y_train)
#metrics to evaluate the model
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
y_pred = model.predict(X_test)
print('Mean Squared Error:', mean_squared_error(Y_test, y_pred))
print('Mean Absolute Error:', mean_absolute_error(Y_test, y_pred))
print('R2 Score:', r2_score(Y_test, y_pred))
# Out:
# Mean Squared Error: 0.8643297266330648
# Mean Absolute Error: 0.6781200515810833
# R2 Score: 0.4678662687687397
